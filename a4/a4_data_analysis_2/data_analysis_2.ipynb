# %%
import re
from matplotlib import style 
import matplotlib.pyplot as plt
import pandas as pd # Pandas = "Python Data Analysis Library"
# np supports arrays and matrices, along with mathematical functions for scientific computing
import numpy as np # Numerical Python
# print ful NumPy array, no ellipsis
np.set_printoptions(threshold=np.inf)

# %%
def get_requirements():
    print("Data Analysis 2")
    print("\nProgram Requirements:\n"
        + "1. Run demo.py.\n"
        + "2. If errors, more than likely missing installations.\n"
        + "3. Test Python Package Installer: pip freeze\n"
        + "4. Research how to install any missing packages:\n"
        + "5. Create at least three functions that are called by the program:\n"
        + "\ta. main(): calls at least two other functions.\n"
        + "\tb. get_requirements(): displays the program requirements.\n"
        + "\tc. data_analysis_2(): displays results as per demo.py."
        + "6. Display graph as per instructionsw/in demo.py.")

# %%
def data_analysis_2():
    url = "https://raw.github.com/vincentarelbundock/Rdatasets/master/csv/Stat2Data/Titanic.csv"
    df = pd.read_csv(url)
        
    print("\n***DataFrame composed of three components: index, columns, and data. Data also known as values.***")
    index = df.index
    columns = df.columns
    values = df.values
        
    print("\n1. Print Indexes:")
    print(index)
        
    print("\n2. Print Columns:")
    print(columns)
        
    print ("\n3. Print Columns (another way):")
    print(df.columns[:])
        
    print("\n3a. Print columns (slicing notation, using all three options):")
        
    print ("\n4. Print (all) values, in array format:")
    print(values)
        
    print("\n5. ***Print component data types:***")
    print("\na) index type")
    print(type(index))
        
    print("\nb) columns type:")
    print(type(columns))
        
    print("\nc) values type:")
    print(type(values))
        
    print("\n6. Print summary of DataFrame (similar to 'describe tablename;' in MySQL):")
    print(df.info())
        
    print("\n7. First five lines (all columns):")
    print(df.head())
        
    #df = df.drop('Unnamed: 0', 1) #drop column after 'Unnamed: 0'
    df = pd.read_csv(url, index_col=[0])
    print("\n8. Print summary of DataFrame (after dropping column 'Unnamed: 0'):")
    print(df.info())
        
    print("\n9. First five lines (after dropping column 'Unnamed: 0'):")
    print(df.head())
        
    print("\n***Precise data selction (data slicing):***")
    print("\n10. Using iloc, return first 3 rows:")
    print(df.iloc[:3])
        
    print("\n11. Using iloc, return last 3 rows (start on index 1310 to end):")
    print(df.iloc[1310:])
        
    print("\n12. Slect rwos 1, 3, and 5; and columns 2, 4, and 6 (includes index coulumn):")
    a = df.iloc[[0, 2, 4], [1, 3, 5]]
    print(a)
        
    print("\n13. Select all rows; and columns 2, 4, and 6 (includes index column):")
    a = df.iloc[:,[1, 3, 5]]
    print(a)
        
    print("\n14. Select rows 1, 3, and 5; and all columns (includes index columns):")
    a = df.iloc[[0, 2, 4], :]
    print(a)
        
    print("\n15. Select all rows, and all columns (includes index column). Note: only first and last 30 records displayed:")
    a = df.iloc[:, :]
    print(a)
        
    print("\n16. Select all rows, and all columns, starting at column 2 (includes index column). Note: only first and last 30 records displayed:")
    a = df.iloc[:, 1:]
    print(a)
        
    print("\n17. Slet row 1, and column 1, (includes index column):")
    a = df.iloc[0:1, 0:1]
    print(a)
        
    print("\n18. Select rows 3-5, and columns 3-5, (includes index column):")
    a = df.iloc[2:5, 2:5]
    print(a)
        
    print("\n19.***Convert pandas DataFrame df to NumPy ndarray, use values command:***")
    b = df.iloc[:, 1:].values
        
    print("\n20. Print data frame type:")
    print(type(df))
        
    print("\n21. Print a type:")
    print(type(a))
        
    print("\n22. Print b type:")
    print(type(b))
        
    print("\n23. Print number of dimensions and items in array (rows, columns). Rember: starting at column 2:")
    print(b.shape)
        
    print("\n24. Print type of items in array. Rember: ndarray is an array of arrays. Each record/item is an array.")
    print(b.dtype)
        
    print("\n25. Pronting a:")
    print(a)
        
    print("\n26. Length a:")
    print(len(a))
        
    print("\n27. Printing b:")
    print(b)
        
    print("\n28. Length b:")
    print(len(b))
        
    print("\n29. Prrint element of (NumPy array) ndarray b in *second* row, *third* column:")
    print(b[1,2])
        
    print("\n30. Print all records for NumPy array column 2:")
    print(b[:,1])
        
    print("\n31. Get passenger names:")
    names = df["Name"]
    print(names)
        
    print("\n32. Find all passengers with name 'Allison' (using regular expressions):")
    for names in names:
        print(re.search(r'(Allison)', names))
        
    print("\n***33. Statistical Anlysis (DataFrame notation):***")
    print("\na) Print mean age:")
    avg = df["Age"].mean()
    print(avg)
        
    print("\nb) Print mean age, rounded to two decimal places:")
    avg = round(df["Age"].mean(), 2)
    print (avg)
        
    print("\nc) Print mean of every column in DataFrame (may not be suitable with certain columns):")
    #avg_all = df.mean(axis=0)
    #print(avg_all)
        
    print("\nd) Print summary statistics (DataFrame notation):")
    describe = df["Age"].describe()
    print(describe)
        
    print("\ne) Print minimum age (DataFrame notation):")
    min = df["Age"].min()
    print(min)
        
    print("\nf) Print maximum age (DataFrame notation):")
    max = df["Age"].max()
    print(max)
        
    print("\ng) Print median age (DataFrame notation):")
    median = df["Age"].median()
    print(median)
        
    print("\nh) Print mode age (DataFrame notation):")
    mode = df["Age"].mode()
    print(mode)
        
    print("\ni) Print number of values (DataFrame notation):")
    count = df["Age"].count()
    print(count)
        
    print("\n***Graph: Display ages of the first 20 passengers (use code from previos assignment)***")
        
    style.use('ggplot')
   # df['DJIA'].plot()
   # df['SP500'].plot()
    df.plot()
    plt.legend()
    plt.show()

# %%
import functions as f


def main():
    get_requirements()
    data_analysis_2()
    
if __name__=="__main__":
    main()
# Out:
# Data Analysis 2
#
# Program Requirements:
# 1. Run demo.py.
# 2. If errors, more than likely missing installations.
# 3. Test Python Package Installer: pip freeze
# 4. Research how to install any missing packages:
# 5. Create at least three functions that are called by the program:
# 	a. main(): calls at least two other functions.
# 	b. get_requirements(): displays the program requirements.
# 	c. data_analysis_2(): displays results as per demo.py.6. Display graph as per instructionsw/in demo.py.
#
# ***DataFrame composed of three components: index, columns, and data. Data also known as values.***
#
# 1. Print Indexes:
# RangeIndex(start=0, stop=1313, step=1)
#
# 2. Print Columns:
# Index(['rownames', 'Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode'], dtype='object')
#
# 3. Print Columns (another way):
# Index(['rownames', 'Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode'], dtype='object')
#
# 3a. Print columns (slicing notation, using all three options):
#
# 4. Print (all) values, in array format:
# [[1 'Allen, Miss Elisabeth Walton' '1st' 29.0 'female' 1 1]
#  [2 'Allison, Miss Helen Loraine' '1st' 2.0 'female' 0 1]
#  [3 'Allison, Mr Hudson Joshua Creighton' '1st' 30.0 'male' 0 0]
#  [4 'Allison, Mrs Hudson JC (Bessie Waldo Daniels)' '1st' 25.0 'female' 0
#   1]
#  [5 'Allison, Master Hudson Trevor' '1st' 0.92 'male' 1 0]
#  [6 'Anderson, Mr Harry' '1st' 47.0 'male' 1 0]
#  [7 'Andrews, Miss Kornelia Theodosia' '1st' 63.0 'female' 1 1]
#  [8 'Andrews, Mr Thomas, jr' '1st' 39.0 'male' 0 0]
#  [9 'Appleton, Mrs Edward Dale (Charlotte Lamson)' '1st' 58.0 'female' 1
#   1]
#  [10 'Artagaveytia, Mr Ramon' '1st' 71.0 'male' 0 0]
#  [11 'Astor, Colonel John Jacob' '1st' 47.0 'male' 0 0]
#  [12 'Astor, Mrs John Jacob (Madeleine Talmadge Force)' '1st' 19.0
#   'female' 1 1]
#  [13 'Aubert, Mrs Leontine Pauline' '1st' nan 'female' 1 1]
#  [14 'Barkworth, Mr Algernon H' '1st' nan 'male' 1 0]
#  [15 'Baumann, Mr John D' '1st' nan 'male' 0 0]
#  [16 'Baxter, Mrs James (Helene DeLaudeniere Chaput)' '1st' 50.0 'female'
#   1 1]
#  [17 'Baxter, Mr Quigg Edmond' '1st' 24.0 'male' 0 0]
#  [18 'Beattie, Mr Thomson' '1st' 36.0 'male' 0 0]
#  [19 'Beckwith, Mr Richard Leonard' '1st' 37.0 'male' 1 0]
#  [20 'Beckwith, Mrs Richard Leonard (Sallie Monypeny)' '1st' 47.0
#   'female' 1 1]
#  [21 'Behr, Mr Karl Howell' '1st' 26.0 'male' 1 0]
#  [22 'Birnbaum, Mr Jakob' '1st' 25.0 'male' 0 0]
#  [23 'Bishop, Mr Dickinson H' '1st' 25.0 'male' 1 0]
#  [24 'Bishop, Mrs Dickinson H (Helen Walton)' '1st' 19.0 'female' 1 1]
#  [25 'Bjornstrm-Steffansson, Mr Mauritz Hakan' '1st' 28.0 'male' 1 0]
#  [26 'Blackwell, Mr Stephen Weart' '1st' 45.0 'male' 0 0]
#  [27 'Blank, Mr Henry' '1st' 39.0 'male' 1 0]
#  [28 'Bonnell, Miss Caroline' '1st' 30.0 'female' 1 1]
#  [29 'Bonnell, Miss Elizabeth' '1st' 58.0 'female' 1 1]
#  [30 'Borebank, Mr John James' '1st' nan 'male' 0 0]
#  [31 'Bowen, Miss Grace Scott' '1st' 45.0 'female' 1 1]
#  [32 'Bowerman, Miss Elsie Edith' '1st' 22.0 'female' 1 1]
#  [33 'Bradley, Mr George' '1st' nan 'male' 1 0]
#  [34 'Brady, Mr John Bertram' '1st' 41.0 'male' 0 0]
#  [35 'Brandeis, Mr Emil' '1st' 48.0 'male' 0 0]
#  [36 'Brewe, Dr Arthur Jackson' '1st' nan 'male' 0 0]
#  [37 'Brown, Mrs James Joseph (Margaret Molly" Tobin)"' '1st' 44.0
#   'female' 1 1]
#  [38 'Brown, Mrs John Murray (Caroline Lane Lamson)' '1st' 59.0 'female'
#   1 1]
#  [39 'Bucknell, Mrs William Robert (Emma Eliza Ward)' '1st' 60.0 'female'
#   1 1]
#  [40 'Butt, Major Archibald Willingham' '1st' 45.0 'male' 0 0]
#  [41 'Calderhead, Mr Edward P' '1st' nan 'male' 1 0]
#  [42 'Candee, Mrs Edward (Helen Churchill Hungerford)' '1st' 53.0
#   'female' 1 1]
#  [43 'Cardeza, Mrs James Warburton Martinez (Charlotte Wardle Drake)'
#   '1st' 58.0 'female' 1 1]
#  [44 'Cardeza, Mr Thomas Drake Martinez' '1st' 36.0 'male' 1 0]
#  [45 'Carlsson, Mr Frans Olof' '1st' 33.0 'male' 0 0]
#  [46 'Carrau, Mr Francisco M' '1st' nan 'male' 0 0]
#  [47 'Carrau, Mr Jose Pedro' '1st' nan 'male' 0 0]
#  [48 'Carter, Mr William Ernest' '1st' 36.0 'male' 1 0]
#  [49 'Carter, Mrs William Ernest (Lucile Polk)' '1st' 36.0 'female' 1 1]
#  [50 'Carter, Miss Lucile Polk' '1st' 14.0 'female' 1 1]
#  [51 'Carter, Master William T II' '1st' 11.0 'male' 1 0]
#  [52 'Case, Mr Howard Brown' '1st' 49.0 'male' 0 0]
#  [53 'Cassebeer, Mrs Henry Arthur jr (Genevieve Fosdick)' '1st' nan
#   'female' 1 1]
#  [54 'Cavendish, Mr Tyrell William' '1st' 36.0 'male' 0 0]
#  [55 'Cavendish, Mrs Tyrell William Julia Florence Siegel' '1st' nan
#   'female' 1 1]
#  [56 'Chaffee, Mr Herbert Fuller' '1st' 46.0 'male' 0 0]
#  [57 'Chaffee, Mrs Herbert Fuller (Carrie Constance Toogood)' '1st' 47.0
#   'female' 1 1]
#  [58 'Chambers, Mr Norman Campbell' '1st' 27.0 'male' 1 0]
#  [59 'Chambers, Mrs Norman Campbell (Bertha Griggs)' '1st' 31.0 'female'
#   1 1]
#  [60 'Cherry, Miss Gladys' '1st' nan 'female' 1 1]
#  [61 'Chevre, Mr Paul' '1st' nan 'male' 1 0]
#  [62 'Chibnall (Bowerman), Mrs Edith Martha' '1st' nan 'female' 1 1]
#  [63 'Chisholm, Mr Roderick Robert' '1st' nan 'male' 0 0]
#  [64 'Clark, Mr Walter Miller' '1st' 27.0 'male' 0 0]
#  [65 'Clark, Mrs Walter Miller (Virginia McDowell)' '1st' 26.0 'female' 1
#   1]
#  [66 'Clifford, Mr George Quincy' '1st' nan 'male' 0 0]
#  [67 'Colley, Mr Edward Pomeroy' '1st' nan 'male' 0 0]
#  [68 'Compton, Mrs Alexander Taylor (Mary Eliza Ingersoll)' '1st' 64.0
#   'female' 1 1]
#  [69 'Compton, Mr Alexander Taylor, Jr' '1st' 37.0 'male' 0 0]
#  [70 'Compton, Miss Sara Rebecca' '1st' 39.0 'female' 1 1]
#  [71 'Cornell, Mrs Robert Clifford (Malvina Helen Lamson)' '1st' 55.0
#   'female' 1 1]
#  [72 'Crafton, Mr John Bertram' '1st' nan 'male' 0 0]
#  [73 'Crosby, Captain Edward Gifford' '1st' 70.0 'male' 0 0]
#  [74 'Crosby, Mrs Edward Gifford (Catherine Elizabeth Halstead)' '1st'
#   69.0 'female' 1 1]
#  [75 'Crosby, Miss Harriet R' '1st' 36.0 'female' 1 1]
#  [76 'Cumings, Mr John Bradley' '1st' 39.0 'male' 0 0]
#  [77 'Cumings, Mrs John Bradley (Florence Briggs Thayer)' '1st' 38.0
#   'female' 1 1]
#  [78 'Daly, Mr Peter Denis ' '1st' nan 'male' 1 0]
#  [79 'Daniel, Mr Robert Williams' '1st' 27.0 'male' 1 0]
#  [80 'Davidson, Mr Thornton' '1st' 31.0 'male' 0 0]
#  [81 'Davidson, Mrs Thornton (Orian Hays)' '1st' 27.0 'female' 1 1]
#  [82 'de Villiers, Madame Berthe' '1st' nan 'female' 1 1]
#  [83 'Dick, Mr Albert Adrian' '1st' 31.0 'male' 1 0]
#  [84 'Dick, Mrs Albert Adrian Vera Gillespie' '1st' 17.0 'female' 1 1]
#  [85 'Dodge, Dr Washington' '1st' nan 'male' 1 0]
#  [86 'Dodge, Mrs Washington (Ruth Vidaver)' '1st' nan 'female' 1 1]
#  [87 'Dodge, Master Washington' '1st' 4.0 'male' 1 0]
#  [88 'Douglas, Mrs Frederick Charles (Suzette Baxter)' '1st' 27.0
#   'female' 1 1]
#  [89 'Douglas, Mr Walter Donald' '1st' 50.0 'male' 0 0]
#  [90 'Douglas, Mrs Walter Donald (Mahala Dutton)' '1st' 48.0 'female' 1 1]
#  [91 'Duff Gordon, Sir Cosmo Edmund' '1st' 49.0 'male' 1 0]
#  [92 'Duff Gordon, Lady (Lucille Wallace Sutherland)' '1st' 48.0 'female'
#   1 1]
#  [93 'Dulles, Mr William Crothers' '1st' 39.0 'male' 0 0]
#  [94 'Earnshaw, Mrs Boulton (Olive Potter)' '1st' 23.0 'female' 1 1]
#  [95 'Eustis, Miss Elizabeth Mussey' '1st' 53.0 'female' 1 1]
#  [96 'Evans, Miss Edith Corse' '1st' 36.0 'female' 0 1]
#  [97 'Flegenheim, Mrs Alfred (Antoinette)' '1st' nan 'female' 1 1]
#  [98 'Flynn, Mr John Irving' '1st' nan 'male' 1 0]
#  [99 'Foreman, Mr Benjamin Laventall' '1st' 30.0 'male' 0 0]
#  [100 'Fortune, Miss Alice Elizabeth' '1st' 24.0 'female' 1 1]
#  [101 'Fortune, Mr Charles Alexander' '1st' 19.0 'male' 0 0]
#  [102 'Fortune, Miss Ethel Flora' '1st' 28.0 'female' 1 1]
#  [103 'Fortune, Miss Mabel' '1st' 23.0 'female' 1 1]
#  [104 'Fortune, Mr Mark' '1st' 64.0 'male' 0 0]
#  [105 'Fortune, Mrs Mark (Mary McDougald)' '1st' 60.0 'female' 1 1]
#  [106 'Franklin, Mr Thomas Parham' '1st' nan 'male' 0 0]
#  [107 'Frauenthal, Dr Henry William' '1st' 49.0 'male' 1 0]
#  [108 'Frauenthal, Mrs Henry William (Clara Heinsheimer)' '1st' nan
#   'female' 1 1]
#  [109 'Frauenthal, Mr Isaac Gerald' '1st' 44.0 'male' 1 0]
#  [110 'Frolicher, Miss Marguerite' '1st' 22.0 'female' 1 1]
#  [111 'Frolicher-Stehli, Mr Maxmillian' '1st' 60.0 'male' 1 0]
#  [112 'Frolicher-Stehli, Mrs Maxmillian (Margaretha Emerentia Stehli)'
#   '1st' 48.0 'female' 1 1]
#  [113 'Futrelle, Mr Jacques' '1st' 37.0 'male' 0 0]
#  [114 'Futrelle, Mrs Jacques (May Peel)' '1st' 35.0 'female' 1 1]
#  [115 'Gee, Mr Arthur H' '1st' 47.0 'male' 0 0]
#  [116 'Gibson, Miss Dorothy' '1st' 22.0 'female' 1 1]
#  [117 'Gibson, Mrs Leonard (Pauline C Boeson)' '1st' 45.0 'female' 1 1]
#  [118 'Goldenberg, Mr Samuel L' '1st' 49.0 'male' 1 0]
#  [119 'Goldenberg, Mrs Samuel L (Edwiga Grabowsko)' '1st' nan 'female' 1
#   1]
#  [120 'Goldschmidt, Mr George B' '1st' 71.0 'male' 0 0]
#  [121 'Gracie, Colonel Archibald IV' '1st' 54.0 'male' 1 0]
#  [122 'Graham, Mr George Edward' '1st' 38.0 'male' 0 0]
#  [123 'Graham, Miss Margaret Edith' '1st' 19.0 'female' 1 1]
#  [124 'Graham, Mrs William Thompson (Edith Junkins)' '1st' 58.0 'female'
#   1 1]
#  [125 'Greenfield, Mrs Leo David (Blanche Strouse)' '1st' 45.0 'female' 1
#   1]
#  [126 'Greenfield, Mr William Bertram' '1st' 23.0 'male' 1 0]
#  [127 'Guggenheim, Mr Benjamin' '1st' 46.0 'male' 0 0]
#  [128 'Harder, Mr George Achilles' '1st' 25.0 'male' 1 0]
#  [129 'Harder, Mrs George Achilles (Dorothy Annan)' '1st' 21.0 'female' 1
#   1]
#  [130 'Harper, Mr Henry Sleeper' '1st' 48.0 'male' 1 0]
#  [131 'Harper, Mrs Henry Sleeper (Myna Haxtun)' '1st' 49.0 'female' 1 1]
#  [132 'Harris, Mr Henry Birkhardt' '1st' 45.0 'male' 0 0]
#  [133 'Harris, Mrs Henry Birkhardt (Irene Wallach)' '1st' 36.0 'female' 1
#   1]
#  [134 'Hawksford, Mr Walter James' '1st' nan 'male' 1 0]
#  [135 'Hays, Mr Charles Melville' '1st' 55.0 'male' 0 0]
#  [136 'Hays, Mrs Charles Melville (Clara Jennings Gregg)' '1st' 52.0
#   'female' 1 1]
#  [137 'Hays, Miss Margaret Bechstein' '1st' 24.0 'female' 1 1]
#  [138 'Head, Mr Christopher' '1st' nan 'male' 0 0]
#  [139 'Hilliard, Mr Herbert Henry' '1st' nan 'male' 0 0]
#  [140 'Hipkins, Mr William Edward' '1st' nan 'male' 0 0]
#  [141 'Hippach, Miss Jean Gertrude' '1st' 16.0 'female' 1 1]
#  [142 'Hippach, Mrs Louis Albert (Ida Sophia Fischer)' '1st' 44.0
#   'female' 1 1]
#  [143 'Hogeboom, Mrs John C (Anna Andrews)' '1st' 51.0 'female' 1 1]
#  [144 'Holverson, Mr Alexander Oskar' '1st' 42.0 'male' 0 0]
#  [145 'Holverson, Mrs Alexander Oskar (Mary Aline Towner)' '1st' 35.0
#   'female' 1 1]
#  [146 'Homer, Mr Harry' '1st' 35.0 'male' 1 0]
#  [147 'Hoyt, Mr Frederick Maxfield' '1st' 38.0 'male' 1 0]
#  [148 'Hoyt, Mrs Frederick Maxfield (Jane Anne Forby)' '1st' 35.0
#   'female' 1 1]
#  [149 'Hoyt, Mr William F' '1st' nan 'male' 0 0]
#  [150 'Isham, Miss Anne Elizabeth' '1st' 50.0 'female' 0 1]
#  [151 'Ismay, Mr Joseph Bruce' '1st' 49.0 'male' 1 0]
#  [152 'Jones, Mr Charles Cresson' '1st' 46.0 'male' 0 0]
#  [153 'Julian, Mr Henry Forbes' '1st' nan 'male' 0 0]
#  [154 'Kent, Mr Edward Austin' '1st' 58.0 'male' 0 0]
#  [155 'Kenyon, Mr Frederick R' '1st' 41.0 'male' 0 0]
#  [156 'Kenyon, Mrs Frederick R (Marion)' '1st' nan 'female' 1 1]
#  [157 'Kimball, Mr Edwin Nelson Jr' '1st' 42.0 'male' 1 0]
#  [158 'Kimball, Mrs Edwin Nelson Jr (Gertrude Parsons)' '1st' 40.0
#   'female' 1 1]
#  [159 'Klaber, Mr Herman' '1st' nan 'male' 0 0]
#  [160 'Leader, Dr Alice Farnham' '1st' nan 'female' 1 1]
#  [161 'Lewy, Mr Ervin G' '1st' nan 'male' 0 0]
#  [162 'Lindeberg-Lind, Mr Erik Gustaf' '1st' 42.0 'male' 0 0]
#  [163 'Lindstrom, Mrs Carl Johan (Sigrid Posse)' '1st' 55.0 'female' 1 1]
#  [164 'Lines, Mrs Ernest H (Elizabeth Lindsey James)' '1st' 50.0 'female'
#   1 1]
#  [165 'Lines, Miss Mary Conover' '1st' 16.0 'female' 1 1]
#  [166 'Lingrey, Mr Edward' '1st' nan 'male' 0 0]
#  [167 'Long, Mr Milton Clyde' '1st' 29.0 'male' 0 0]
#  [168 'Longley, Miss Gretchen Fiske' '1st' 21.0 'female' 1 1]
#  [169 'Loring, Mr Joseph Holland' '1st' 30.0 'male' 0 0]
#  [170 'Madill, Miss Georgette Alexandra' '1st' 15.0 'female' 1 1]
#  [171 'Maguire, Mr John Edward' '1st' 30.0 'male' 0 0]
#  [172 'Marechal, Mr Pierre' '1st' nan 'male' 1 0]
#  [173 'Marvin, Mr Daniel Warner' '1st' nan 'male' 0 0]
#  [174 'Marvin, Mrs Daniel Warner (Mary Graham Carmichael Farquarson)'
#   '1st' nan 'female' 1 1]
#  [175 'McCaffry, Mr Thomas Francis' '1st' 46.0 'male' 0 0]
#  [176 'McCarthy, Mr Timothy J' '1st' 54.0 'male' 0 0]
#  [177 'McGough, Mr James R' '1st' 36.0 'male' 1 0]
#  [178 'Meyer, Mr Edgar Joseph' '1st' 28.0 'male' 0 0]
#  [179 'Meyer, Mrs Edgar Joseph (Leila Saks)' '1st' nan 'female' 1 1]
#  [180 'Millet, Mr Francis Davis' '1st' 65.0 'male' 0 0]
#  [181 'Minahan, Miss Daisy E' '1st' 33.0 'female' 1 1]
#  [182 'Minahan, Dr William Edward' '1st' 44.0 'male' 0 0]
#  [183 'Minahan, Mrs William Edward (Lillian E Thorpe)' '1st' 37.0
#   'female' 1 1]
#  [184 'Mock, Mr Philip E' '1st' nan 'male' 1 0]
#  [185 'Molson, Mr Harry Markland' '1st' 55.0 'male' 0 0]
#  [186 'Moore, Mr Clarence Bloomfield' '1st' 47.0 'male' 0 0]
#  [187 'Natsch, Mr Charles H' '1st' 36.0 'male' 0 0]
#  [188 'Newell, Mr Arthur Webster' '1st' 58.0 'male' 0 0]
#  [189 'Newell, Miss Madeleine' '1st' 31.0 'female' 1 1]
#  [190 'Newell, Miss Marjorie' '1st' 23.0 'female' 1 1]
#  [191 'Newsom, Miss Helen Monypeny' '1st' 19.0 'female' 1 1]
#  [192 'Nicholson, Mr Arthur Ernest' '1st' 64.0 'male' 0 0]
#  [193 'Omont, Mr A Fernand' '1st' nan 'male' 1 0]
#  [194 'Ostby, Mr Engelhart Cornelius' '1st' 64.0 'male' 0 0]
#  [195 'Ostby, Miss Helen Raghnild' '1st' 22.0 'female' 1 1]
#  [196 'Ovies y Rodriguez, Mr Servando' '1st' 28.0 'male' 0 0]
#  [197 'Parr, Mr William Henry Marsh' '1st' nan 'male' 0 0]
#  [198 'Partner, Mr Austin' '1st' nan 'male' 0 0]
#  [199 'Payne, Mr Vivian Ponsonby' '1st' 22.0 'male' 0 0]
#  [200 'Pears, Mr Thomas' '1st' nan 'male' 0 0]
#  [201 'Pears, Mrs Thomas (Edith)' '1st' nan 'female' 1 1]
#  [202 'Penasco, Mr Victor de Satode' '1st' 18.0 'male' 0 0]
#  [203 'Penasco, Mrs Victor de Satode (Josefa de Soto)' '1st' 17.0
#   'female' 1 1]
#  [204 'Peuchen, Major Arthur Godfrey' '1st' 52.0 'male' 1 0]
#  [205 'Porter, Mr Walter Chamberlain' '1st' 46.0 'male' 0 0]
#  [206 'Potter, Mrs Thomas, Jr (Lily Alexenia Wilson)' '1st' 56.0 'female'
#   1 1]
#  [207 'Reuchlin, Jonkheer John George' '1st' nan 'male' 0 0]
#  [208 'Rheims, Mr George Lucien' '1st' nan 'male' 1 0]
#  [209 'Robert, Mrs Edward Scott (Elisabeth Walton McMillan)' '1st' 43.0
#   'female' 1 1]
#  [210 'Roebling, Mr Washington Augustus 2nd' '1st' 31.0 'male' 0 0]
#  [211 'Romaine, Mr Charles Hallace' '1st' nan 'male' 1 0]
#  [212 'Rood, Mr Hugh R' '1st' nan 'male' 0 0]
#  [213 'Rosenbaum (Russell), Miss Edith Louise' '1st' 33.0 'female' 1 1]
#  [214 'Ross, Mr John Hugo' '1st' nan 'male' 0 0]
#  [215 'Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)' '1st'
#   27.0 'female' 1 1]
#  [216 'Rothschild, Mr Martin' '1st' 55.0 'male' 0 0]
#  [217 'Rothschild, Mrs Martin (Elizabeth L Barrett)' '1st' 54.0 'female'
#   1 1]
#  [218 'Rowe, Mr Alfred G' '1st' nan 'male' 0 0]
#  [219 'Ryerson, Mr Arthur Larned' '1st' 61.0 'male' 0 0]
#  [220 'Ryerson, Mrs Arthur Larned (Emily Maria Borie)' '1st' 48.0
#   'female' 1 1]
#  [221 'Ryerson, Miss Emily Borie' '1st' 18.0 'female' 1 1]
#  [222 'Ryerson, Master John Borie' '1st' 13.0 'male' 1 0]
#  [223 'Ryerson, Miss Susan (Suzette) Parker' '1st' 21.0 'female' 1 1]
#  [224 'Saalfeld, Mr Adolphe' '1st' nan 'male' 1 0]
#  [225 'Salomon, Mr Abraham L' '1st' nan 'male' 1 0]
#  [226 'Schabert, Mrs Paul (Emma Mock)' '1st' nan 'female' 1 1]
#  [227 'Seward, Mr Frederic Kimber' '1st' 34.0 'male' 1 0]
#  [228 'Shutes, Miss Elizabeth W' '1st' 40.0 'female' 1 1]
#  [229 'Silverthorne, Mr Spencer Victor' '1st' 36.0 'male' 1 0]
#  [230 'Silvey, Mr William Baird' '1st' 50.0 'male' 0 0]
#  [231 'Silvey, Mrs William Baird (Alice Munger)' '1st' 39.0 'female' 1 1]
#  [232 'Simonius-Blumer, Col Alfons' '1st' 56.0 'male' 1 0]
#  [233 'Sloper, Mr William Thompson' '1st' 28.0 'male' 1 0]
#  [234 'Smart, Mr John Montgomery' '1st' 56.0 'male' 0 0]
#  [235 'Smith, Mr James Clinch' '1st' 56.0 'male' 0 0]
#  [236 'Smith, Mr Lucien Philip' '1st' 24.0 'male' 0 0]
#  [237 'Smith, Mrs Lucien Philip (Mary Eloise Hughes' '1st' 18.0 'female'
#   1 1]
#  [238 'Smith, Mr Richard William' '1st' nan 'male' 0 0]
#  [239 'Snyder, Mr John Pillsbury' '1st' 24.0 'male' 1 0]
#  [240 'Snyder, Mrs John Pillsbury (Nelle Stevenson)' '1st' 23.0 'female'
#   1 1]
#  [241 'Spedden, Mr Frederick Oakley' '1st' 45.0 'male' 1 0]
#  [242 'Spedden, Mrs Frederick Oakley (Margaretta Corning Stone)' '1st'
#   40.0 'female' 1 1]
#  [243 'Spedden, Master Robert Douglas' '1st' 6.0 'male' 1 0]
#  [244 'Spencer, Mr William Augustus' '1st' 57.0 'male' 0 0]
#  [245 'Spencer, Mrs William Augustus (Marie Eugenie)' '1st' nan 'female'
#   1 1]
#  [246 'Staehlin, Dr Max' '1st' 32.0 'male' 1 0]
#  [247 'Stead, Mr William Thomas' '1st' 62.0 'male' 0 0]
#  [248 'Stengel, Mr Charles Emil Henry' '1st' 54.0 'male' 1 0]
#  [249 'Stengel, Mrs Charles Emil Henry (Annie May Morris)' '1st' 43.0
#   'female' 1 1]
#  [250 'Stephenson, Mrs Walter Bertram (Martha Eustis)' '1st' 52.0
#   'female' 1 1]
#  [251 'Stewart, Mr Albert A' '1st' nan 'male' 0 0]
#  [252 'Stone, Mrs George Nelson (Martha E)' '1st' 62.0 'female' 1 1]
#  [253 'Straus, Mr Isidor' '1st' 67.0 'male' 0 0]
#  [254 'Straus, Mrs Isidor (Ida Blun)' '1st' 63.0 'female' 0 1]
#  [255 'Sutton, Mr Frederick' '1st' 61.0 'male' 0 0]
#  [256 'Swift, Mrs Frederick Joel (Margaret Welles Barron)' '1st' 46.0
#   'female' 1 1]
#  [257 'Taussig, Mr Emil' '1st' 52.0 'male' 0 0]
#  [258 'Taussig, Mrs Emil (Tillie Mandelbaum)' '1st' 39.0 'female' 1 1]
#  [259 'Taussig, Miss Ruth' '1st' 18.0 'female' 1 1]
#  [260 'Taylor, Mr Elmer Zebley' '1st' 48.0 'male' 1 0]
#  [261 'Taylor, Mrs Elmer Zebley (Juliet Cummins Wright)' '1st' nan
#   'female' 1 1]
#  [262 'Thayer, Mr John Borland' '1st' 49.0 'male' 0 0]
#  [263 'Thayer, Mrs John Borland (Marian Longstreth Morris)' '1st' 39.0
#   'female' 1 1]
#  [264 'Thayer, Mr John Borland, jr' '1st' 17.0 'male' 1 0]
#  [265 'Thorne, Mr George (alias of: Mr George Rosenshine)' '1st' 46.0
#   'male' 0 0]
#  [266 'Thorne, Mrs Gertrude Maybelle' '1st' nan 'female' 1 1]
#  [267 'Tucker, Mr Gilbert Milligan, jr' '1st' 31.0 'male' 1 0]
#  [268 'Uruchurtu, Mr Manuel E' '1st' nan 'male' 0 0]
#  [269 'Van Derhoef, Mr Wyckoff' '1st' 61.0 'male' 0 0]
#  [270 'Walker, Mr William Anderson' '1st' 47.0 'male' 0 0]
#  [271 'Warren, Mr Frank Manley' '1st' 64.0 'male' 0 0]
#  [272 'Warren, Mrs Frank Manley (Anna S Atkinson)' '1st' 60.0 'female' 1
#   1]
#  [273 'Weir, Col John' '1st' 60.0 'male' 0 0]
#  [274 'White, Mrs J Stuart (Ella Holmes)' '1st' 55.0 'female' 1 1]
#  [275 'White, Mr Percival Wayland' '1st' 54.0 'male' 0 0]
#  [276 'White, Mr Richard Frasar' '1st' 21.0 'male' 0 0]
#  [277 'Wick, Mr George Dennick' '1st' 57.0 'male' 0 0]
#  [278 'Wick, Mrs George Dennick (Martha Hitchcock)' '1st' 45.0 'female' 1
#   1]
#  [279 'Wick, Miss Mary Natalie' '1st' 31.0 'female' 1 1]
#  [280 'Widener, Mr George Dunton' '1st' 50.0 'male' 0 0]
#  [281 'Widener, Mrs George Dunton (Eleanor Elkins)' '1st' 50.0 'female' 1
#   1]
#  [282 'Widener, Mr Harry Elkins' '1st' 27.0 'male' 0 0]
#  [283 'Willard, Miss Constance' '1st' 20.0 'female' 1 1]
#  [284 'Williams, Mr Charles Duane' '1st' 51.0 'male' 0 0]
#  [285 'Williams, Mr Fletcher Lambert' '1st' nan 'male' 0 0]
#  [286 'Williams, Mr Richard Norris II' '1st' 21.0 'male' 1 0]
#  [287 'Woolner, Mr Hugh' '1st' nan 'male' 1 0]
#  [288 'Wright, Mr George' '1st' nan 'male' 0 0]
#  [289 'Young, Miss Marie Grice' '1st' 36.0 'female' 1 1]
#  [290 'Barber, Ms ' '1st' nan 'female' 1 1]
#  [291 'Bazzani, Ms Albina' '1st' nan 'female' 1 1]
#  [292 'Bidois, Miss Rosalie' '1st' nan 'female' 1 1]
#  [293 'Bird, Ms Ellen' '1st' nan 'female' 1 1]
#  [294 'Bissetti, Ms Amelia' '1st' nan 'female' 1 1]
#  [295 'Burns, Ms Elizabeth Margaret' '1st' nan 'female' 1 1]
#  [296 'Chaudanson, Ms         Victorine' '1st' nan 'female' 1 1]
#  [297 'Cleaver, Ms Alice' '1st' nan 'female' 1 1]
#  [298 'Daniels, Ms Sarah' '1st' nan 'female' 1 1]
#  [299 'Endres, Miss Caroline Louise' '1st' nan 'female' 1 1]
#  [300 'Farthing, Mr John' '1st' nan 'male' 0 0]
#  [301 'Fleming, Ms Margaret' '1st' nan 'female' 0 1]
#  [302 'Francatelli, Ms Laura Mabel' '1st' nan 'female' 1 1]
#  [303 'Fry, Mr Richard' '1st' nan 'male' 0 0]
#  [304 'Geiger, Miss Emily ' '1st' nan 'female' 1 1]
#  [305 'Giglio, Mr Victor' '1st' nan 'male' 0 0]
#  [306 'Harrington, Mr Charles' '1st' nan 'male' 0 0]
#  [307 'Harrison, Mr William   Henry' '1st' 40.0 'male' 0 0]
#  [308 'Hassah, Mr Hamad' '1st' nan 'male' 0 0]
#  [309 'Icabad (Icabod), Ms' '1st' nan 'female' 1 1]
#  [310 'Keeping, Mr Edwin' '1st' 32.0 'male' 0 0]
#  [311 'Kenchen, Ms Amelia' '1st' nan 'female' 1 1]
#  [312 'LeRoy, Miss Berthe' '1st' nan 'female' 1 1]
#  [313 'Lesneur, Mr Gustave' '1st' nan 'male' 0 0]
#  [314 'Maloney, Ms' '1st' nan 'female' 1 1]
#  [315 'Oliva, Mlle' '1st' nan 'female' 0 1]
#  [316 'Pericault, Ms' '1st' nan 'female' 1 1]
#  [317 'Ringhini, Mr Sante' '1st' 33.0 'male' 0 0]
#  [318 'Robbins, Mr Victor' '1st' nan 'male' 0 0]
#  [319 'Segesser, Mlle Emma' '1st' nan 'female' 1 1]
#  [320 'Seredeca, Ms' '1st' nan 'female' 0 1]
#  [321 'Ward, Ms Anna' '1st' nan 'female' 0 1]
#  [322 'Wilson, Ms Helen' '1st' nan 'female' 1 1]
#  [323 'Abelson, Mr Samuel' '2nd' 30.0 'male' 0 0]
#  [324 'Abelson, Mrs Samuel (Anna)' '2nd' 28.0 'female' 1 1]
#  [325 'Andrew, Mr Edgar Samuel' '2nd' 18.0 'male' 0 0]
#  [326 'Andrew, Mr Frank' '2nd' nan 'male' 0 0]
#  [327 'Angle, Mr William A' '2nd' 34.0 'male' 0 0]
#  [328 'Angle, Mrs William A (Florence)' '2nd' 32.0 'female' 1 1]
#  [329 'Ashby, Mr John' '2nd' 57.0 'male' 0 0]
#  [330 'Bailey, Mr Percy Andrew' '2nd' 18.0 'male' 0 0]
#  [331 'Baimbrigge, Mr Charles R' '2nd' 23.0 'male' 0 0]
#  [332 'Balls, Mrs Ada E Hall' '2nd' 36.0 'female' 1 1]
#  [333 'Banfield, Mr Frederick J' '2nd' 28.0 'male' 0 0]
#  [334 'Bateman, Rev Robert James' '2nd' 51.0 'male' 0 0]
#  [335 'Beane, Mr Edward' '2nd' 32.0 'male' 1 0]
#  [336 'Beane, Mrs Edward (Ethel Clarke)' '2nd' 19.0 'female' 1 1]
#  [337 'Beauchamp, Mr Henry James' '2nd' 28.0 'male' 0 0]
#  [338 'Becker, Mrs Allen Oliver (Nellie E Baumgardner)' '2nd' 36.0
#   'female' 1 1]
#  [339 'Becker, Miss Marion Louise' '2nd' 4.0 'female' 1 1]
#  [340 'Becker, Master Richard F' '2nd' 1.0 'male' 1 0]
#  [341 'Becker, Miss Ruth Elizabeth' '2nd' 12.0 'female' 1 1]
#  [342 'Beesley, Mr Lawrence' '2nd' 34.0 'male' 1 0]
#  [343 'Bentham, Miss Lilian W' '2nd' 19.0 'female' 1 1]
#  [344 'Berriman, Mr William S' '2nd' 23.0 'male' 0 0]
#  [345 'Botsford, Mr William Hull' '2nd' 26.0 'male' 0 0]
#  [346 'Bowenur, Mr Solomon' '2nd' nan 'male' 0 0]
#  [347 'Bracken, Mr James H' '2nd' 27.0 'male' 0 0]
#  [348 'Brown, Miss Edith E' '2nd' 15.0 'female' 1 1]
#  [349 'Brown, Mr Thomas William Solomon' '2nd' 45.0 'male' 0 0]
#  [350 'Brown, Mrs Thomas William Solomon (Elizabeth C)' '2nd' 40.0
#   'female' 1 1]
#  [351 'Bryhl, Miss Dagmar' '2nd' 20.0 'female' 1 1]
#  [352 'Bryhl, Mr Kurt Arnold Gottfrid' '2nd' 25.0 'male' 0 0]
#  [353 'Buss, Miss Kate' '2nd' 36.0 'female' 1 1]
#  [354 'Butler, Mr Reginald Fenton' '2nd' 25.0 'male' 0 0]
#  [355 'Byles, Rev Thomas Roussel D' '2nd' nan 'male' 0 0]
#  [356 'Bystrom, Mrs Carolina' '2nd' 42.0 'female' 1 1]
#  [357 'Caldwell, Mr Albert Francis' '2nd' 26.0 'male' 1 0]
#  [358 'Caldwell, Mrs Albert Francis (Sylvia Mae Harbaugh)' '2nd' 26.0
#   'female' 1 1]
#  [359 'Caldwell, Master Alden Gates' '2nd' 0.83 'male' 1 0]
#  [360 'Cameron, Miss Clear' '2nd' 31.0 'female' 1 1]
#  [361 'Campbell, Mr William' '2nd' nan 'male' 0 0]
#  [362 'Carbines, Mr William' '2nd' 19.0 'male' 0 0]
#  [363 'Carter, Rev Ernest Courtenay' '2nd' 54.0 'male' 0 0]
#  [364 'Carter, Mrs Ernest Courtenay (Lillian Hughes)' '2nd' 44.0 'female'
#   0 1]
#  [365 'Chapman, Mr Charles Henry' '2nd' 52.0 'male' 0 0]
#  [366 'Chapman, Mr John Henry' '2nd' 30.0 'male' 0 0]
#  [367 'Chapman, Mrs John Henry (Elizabeth Lawry)' '2nd' 30.0 'female' 0 1]
#  [368 'Christy, Mrs Alice Frances' '2nd' nan 'female' 1 1]
#  [369 'Christy, Miss Julie' '2nd' nan 'female' 1 1]
#  [370 'Clarke, Mr Charles V' '2nd' 29.0 'male' 0 0]
#  [371 'Clarke, Mrs Charles V (Ada Maria)' '2nd' nan 'female' 1 1]
#  [372 'Coleridge, Mr Reginald Charles' '2nd' 29.0 'male' 0 0]
#  [373 'Collander, Mr Erik' '2nd' 27.0 'male' 0 0]
#  [374 'Collett, Mr Sidney C Stuart' '2nd' 24.0 'male' 1 0]
#  [375 'Collyer, Mr Harvey' '2nd' 35.0 'male' 0 0]
#  [376 'Collyer, Mrs Harvey (Charlotte Tate)' '2nd' 31.0 'female' 1 1]
#  [377 'Collyer, Miss Marjorie' '2nd' 8.0 'female' 1 1]
#  [378 'Cook, Mrs Selena Rogers' '2nd' 22.0 'female' 0 1]
#  [379 'Corbett, Mrs Walter H (Irene Colvin)' '2nd' 30.0 'female' 0 1]
#  [380 'Corey, Mrs Percy C (Mary Phyllis Elizabeth Miller)' '2nd' nan
#   'female' 0 1]
#  [381 'Cotterill, Mr Harry' '2nd' 20.0 'male' 0 0]
#  [382 'Cunningham, Mr Alfred Fleming' '2nd' nan 'male' 0 0]
#  [383 'Davies, Mr Charles Henry' '2nd' 21.0 'male' 0 0]
#  [384 'Davis, Mrs Agnes' '2nd' 49.0 'female' 1 1]
#  [385 'Davis, Master John Morgan' '2nd' 8.0 'male' 1 0]
#  [386 'Davis, Miss Mary' '2nd' 28.0 'female' 1 1]
#  [387 'Deacon, Mr Percy' '2nd' 18.0 'male' 0 0]
#  [388 'de Brito, Mr Jose Joaquim' '2nd' nan 'male' 0 0]
#  [389 'del Carlo, Mr Sebastiano' '2nd' 28.0 'male' 0 0]
#  [390 'del Carlo, Mrs Sebastiano (Argenia Genovese)' '2nd' 22.0 'female'
#   1 1]
#  [391 'Denbury, Mr Herbert' '2nd' 25.0 'male' 0 0]
#  [392 'Dibden, Mr William' '2nd' 18.0 'male' 0 0]
#  [393 'Doling, Mrs Ada' '2nd' 32.0 'female' 1 1]
#  [394 'Doling, Miss Elsie' '2nd' 18.0 'female' 1 1]
#  [395 'Downton (?Douton), Mr William James' '2nd' nan 'male' 0 0]
#  [396 'Drew, Mr James Vivian' '2nd' 42.0 'male' 0 0]
#  [397 'Drew, Mrs James Vivian (Lulu Thorne Christian)' '2nd' 34.0
#   'female' 1 1]
#  [398 'Drew, Master Marshall Brines' '2nd' 8.0 'male' 1 0]
#  [399 'Duran y More, Miss Asuncion' '2nd' nan 'female' 1 1]
#  [400 'Duran y More, Miss Florentina' '2nd' nan 'female' 1 1]
#  [401 'Eitemiller, Mr George Floyd' '2nd' 23.0 'male' 0 0]
#  [402 'Enander, Mr Ingvar' '2nd' 21.0 'male' 0 0]
#  [403 'Fahlstrom, Mr Arne Jonas' '2nd' 19.0 'male' 0 0]
#  [404 'Faunthorpe, Mr Harry' '2nd' nan 'male' 0 0]
#  [405 'Faunthorpe, Mrs Lizzie (see Wilkinson, E)' '2nd' nan 'female' 1 1]
#  [406 'Fillbrook, Mr Charles' '2nd' nan 'male' 0 0]
#  [407 'Fox, Mr Stanley H' '2nd' 38.0 'male' 0 0]
#  [408 'Frost, Mr Anthony (Archie) W' '2nd' nan 'male' 0 0]
#  [409 'Funk, Miss Annie C' '2nd' 38.0 'female' 0 1]
#  [410 'Fynney, Mr Joseph J' '2nd' 35.0 'male' 0 0]
#  [411 'Gale, Mr Harry' '2nd' 35.0 'male' 0 0]
#  [412 'Gale, Mr Shadrach' '2nd' 38.0 'male' 0 0]
#  [413 'Garside, Miss Ethel' '2nd' 24.0 'female' 1 1]
#  [414 'Gaskell, Mr Alfred' '2nd' 16.0 'male' 0 0]
#  [415 'Gavey, Mr Lawrence' '2nd' 26.0 'male' 0 0]
#  [416 'Gilbert, Mr William' '2nd' 45.0 'male' 0 0]
#  [417 'Giles, Mr Edgar' '2nd' 24.0 'male' 0 0]
#  [418 'Giles, Mr Frederick' '2nd' 21.0 'male' 0 0]
#  [419 'Giles, Mr Ralph' '2nd' 22.0 'male' 0 0]
#  [420 'Gill, Mr John W' '2nd' nan 'male' 0 0]
#  [421 'Gillespie, Mr William' '2nd' 34.0 'male' 0 0]
#  [422 'Givard, Mr Hans Christensen' '2nd' 30.0 'male' 0 0]
#  [423 'Greenberg, Mr Samuel' '2nd' 50.0 'male' 0 0]
#  [424 'Hale, Mr Reginald' '2nd' 30.0 'male' 0 0]
#  [425 'Hamalainen, Mrs William (Anna)' '2nd' 23.0 'female' 1 1]
#  [426 'Hamalainen, Master Viljo' '2nd' 1.0 'male' 1 0]
#  [427 'Harbeck, Mr William H' '2nd' 44.0 'male' 0 0]
#  [428 'Harper, Rev John' '2nd' 28.0 'male' 0 0]
#  [429 'Harper, Miss Nina' '2nd' 6.0 'female' 1 1]
#  [430 'Harris, Mr George' '2nd' 30.0 'male' 1 0]
#  [431 'Harris, Mr Walter' '2nd' nan 'male' 0 0]
#  [432 'Hart, Mr Benjamin' '2nd' 43.0 'male' 0 0]
#  [433 'Hart, Mrs Benjamin (Esther)' '2nd' 45.0 'female' 1 1]
#  [434 'Hart, Miss Eva Miriam' '2nd' 7.0 'female' 1 1]
#  [435 'Herman, Miss Alice' '2nd' 24.0 'female' 1 1]
#  [436 'Herman, Miss Kate' '2nd' 24.0 'female' 1 1]
#  [437 'Herman, Mr Samuel' '2nd' 49.0 'male' 0 0]
#  [438 'Herman, Mrs Samuel (Jane Laver)' '2nd' 48.0 'female' 1 1]
#  [439 'Hewlett, Mrs Mary D' '2nd' nan 'female' 1 1]
#  [440 'Hickman, Mr Leonard Mark' '2nd' 34.0 'male' 0 0]
#  [441 'Hickman, Mr Lewis' '2nd' 32.0 'male' 0 0]
#  [442 'Hickman, Mr Stanley George' '2nd' 21.0 'male' 0 0]
#  [443 'Hiltunen, Miss Marta' '2nd' 18.0 'female' 0 1]
#  [444 'Hocking, Mrs Elizabeth' '2nd' 53.0 'female' 1 1]
#  [445 'Hocking, Mr George' '2nd' 23.0 'male' 0 0]
#  [446 'Hocking, Miss Ellen (Nellie)' '2nd' 21.0 'female' 1 1]
#  [447 'Hocking, Mr Samuel James' '2nd' nan 'male' 0 0]
#  [448 'Hodges, Mr Henry Price' '2nd' 52.0 'male' 0 0]
#  [449 'Hold, Mr Stephen' '2nd' 42.0 'male' 0 0]
#  [450 'Hold, Mrs Stephen (Annie Margaret)' '2nd' 36.0 'female' 1 1]
#  [451 'Hood, Mr Ambrose, Jr' '2nd' 21.0 'male' 0 0]
#  [452 'Hosono, Mr Masafumi' '2nd' 41.0 'male' 1 0]
#  [453 'Howard, Mr Benjamin' '2nd' nan 'male' 0 0]
#  [454 'Howard, Mrs Benjamin (Ellen Truelove)' '2nd' nan 'female' 0 1]
#  [455 'Hunt, Mr George Henry' '2nd' 33.0 'male' 0 0]
#  [456 'Ilett, Miss Bertha' '2nd' 17.0 'female' 1 1]
#  [457 'Jacobsohn Mr Samuel' '*' nan 'male' 0 0]
#  [458 'Jacobsohn, Mrs Sidney Samuel (Amy Frances Christy)' '2nd' nan
#   'female' 1 1]
#  [459 'Jarvis, Mr John Denzil' '2nd' nan 'male' 0 0]
#  [460 'Jefferys, Mr Clifford' '2nd' nan 'male' 0 0]
#  [461 'Jefferys, Mr Ernest' '2nd' nan 'male' 0 0]
#  [462 'Jenkin, Mr Stephen Curnow' '2nd' nan 'male' 0 0]
#  [463 'Jerwan, Mrs Amin S (Marie Thuillard)' '2nd' 23.0 'female' 1 1]
#  [464 'Kantor, Mr Sinai' '2nd' 34.0 'male' 0 0]
#  [465 'Kantor, Mrs Sinai (Miriam Sternim)' '2nd' nan 'female' 1 1]
#  [466 'Karnes, Mrs J Frank (Claire Bennett)' '2nd' 22.0 'female' 0 1]
#  [467 'Keane, Mr Daniel' '2nd' nan 'male' 0 0]
#  [468 'Keane, Miss Nora A' '2nd' nan 'female' 1 1]
#  [469 'Kelly, Mrs Florence (Fannie)' '2nd' 45.0 'female' 1 1]
#  [470 'Kirkland, Rev Charles Leonard' '2nd' nan 'male' 0 0]
#  [471 'Knight, Mr Robert' '2nd' nan 'male' 0 0]
#  [472 'Kvillner, Mr Johan Henrik Johannesson' '2nd' 31.0 'male' 0 0]
#  [473 'Lahtinen, Rev William' '2nd' 30.0 'male' 0 0]
#  [474 'Lahtinen, Mrs William (Anna Sylvan)' '2nd' 26.0 'female' 0 1]
#  [475 'Lamb, Mr John James' '2nd' nan 'male' 0 0]
#  [476 'Lemore, Mrs Amelia' '2nd' 34.0 'female' 1 1]
#  [477 'LaRoche, Mr Joseph' '2nd' 26.0 'male' 0 0]
#  [478 'LaRoche, Mrs Joseph (Juliet)' '2nd' 22.0 'female' 1 1]
#  [479 'LaRoche, Miss Louise' '2nd' 1.0 'female' 1 1]
#  [480 'LaRoche, Miss Simonne' '2nd' 3.0 'female' 1 1]
#  [481 'Lehmann, Miss Bertha' '2nd' nan 'female' 1 1]
#  [482 'Leitch, Miss Jessie' '2nd' nan 'female' 1 1]
#  [483 'Levy, Mr Rene Jacques' '2nd' nan 'male' 0 0]
#  [484 'Leyson, Mr Robert William Norman' '2nd' 25.0 'male' 0 0]
#  [485 'Lingan, Mr John' '2nd' nan 'male' 0 0]
#  [486 'Louch, Mr Charles Alexander' '2nd' 48.0 'male' 0 0]
#  [487 'Louch, Mrs Charles Alexander (Alice Adelaide)' '2nd' nan 'female'
#   1 1]
#  [488 'Mack, Mrs Mary' '2nd' 57.0 'female' 0 1]
#  [489 'Malachard, Mr Noel' '2nd' nan 'male' 0 0]
#  [490 'Mallet, Mr Albert' '2nd' nan 'male' 0 0]
#  [491 'Mallet, Mrs Albert (Antoinette)' '2nd' nan 'female' 1 1]
#  [492 'Mallet, Master Andre' '2nd' 2.0 'male' 1 0]
#  [493 'Mangiavacchi, Mr Serafino Emilio' '2nd' nan 'male' 0 0]
#  [494 'Mantvila, Rev Joseph' '2nd' 27.0 'male' 0 0]
#  [495 'Marshall, Mrs Kate Louise Phillips' '2nd' 19.0 'female' 1 1]
#  [496 'Matthews, Mr William John' '2nd' 30.0 'male' 0 0]
#  [497 'Maybery, Mr Frank H' '2nd' 20.0 'male' 0 0]
#  [498 'McCrae, Mr Arthur Gordon' '2nd' 45.0 'male' 0 0]
#  [499 'McCrie, Mr James Matthew' '2nd' nan 'male' 0 0]
#  [500 'McKane, Mr Peter D' '2nd' 46.0 'male' 0 0]
#  [501 'Mellenger, Mrs Elizabeth Anne' '2nd' 41.0 'female' 1 1]
#  [502 'Mellenger, Miss Madeleine Violet' '2nd' 13.0 'female' 1 1]
#  [503 'Mellor, Mr William John' '2nd' 19.0 'male' 1 0]
#  [504 'Meyer, Mr August' '2nd' 30.0 'male' 0 0]
#  [505 'Milling, Mr Jacob Christian' '2nd' 48.0 'male' 0 0]
#  [506 'Mitchell, Mr Henry Michael' '2nd' 71.0 'male' 0 0]
#  [507 'Moraweck, Dr Ernest' '2nd' 54.0 'male' 0 0]
#  [508 'Morley, Mr William' '2nd' nan 'male' 0 0]
#  [509 'Mudd, Mr Thomas C' '2nd' nan 'male' 0 0]
#  [510 'Myles, Mr Thomas Francis' '2nd' 64.0 'male' 0 0]
#  [511 'Nasser (Nasrallah), Mr Nicholas' '2nd' 32.0 'male' 0 0]
#  [512 'Nasser (Nasrallah), Mrs Nicholas' '2nd' 18.0 'female' 1 1]
#  [513 'Navratil, Master Edmond Roger' '2nd' 2.0 'male' 1 0]
#  [514 'Navratil, Mr Michel' '2nd' 32.0 'male' 0 0]
#  [515 'Navratil, Master Michel M' '2nd' 3.0 'male' 1 0]
#  [516 'Nesson, Mr Israel' '2nd' 26.0 'male' 0 0]
#  [517 'Nicholls, Mr Joseph Charles' '2nd' 19.0 'male' 0 0]
#  [518 'Norman, Mr Robert Douglas' '2nd' nan 'male' 0 0]
#  [519 'Nourney, Mr Alfred (aka Baron von Drachstedt)' '2nd' 20.0 'male' 1
#   0]
#  [520 'Nye, Mrs Elizabeth Ramell' '2nd' 29.0 'female' 1 1]
#  [521 'Otter, Mr Richard' '2nd' 39.0 'male' 0 0]
#  [522 'Oxenham, Mr Percy Thomas' '2nd' 22.0 'male' 1 0]
#  [523 'Padro y Manent, Mr Julian' '2nd' nan 'male' 1 0]
#  [524 'Pain, Dr Alfred' '2nd' 24.0 'male' 0 0]
#  [525 'Pallas y Castello, Mr Emilio' '2nd' nan 'male' 1 0]
#  [526 'Parker, Mr Clifford R' '2nd' 28.0 'male' 0 0]
#  [527 'Parkes, Mr Francis (Frank)' '2nd' nan 'male' 0 0]
#  [528 'Parrish, Mrs Lutie Davis' '2nd' 50.0 'female' 1 1]
#  [529 'Pengelly, Mr Frederick' '2nd' 20.0 'male' 0 0]
#  [530 'Peruschitz, Rev Joseph M' '2nd' 40.0 'male' 0 0]
#  [531 'Phillips, Miss Alice' '2nd' 42.0 'female' 1 1]
#  [532 'Phillips, Mr Robert' '2nd' 21.0 'male' 0 0]
#  [533 'Pinsky, Miss Rosa' '2nd' 32.0 'female' 1 1]
#  [534 'Ponesell, Mr Martin' '2nd' 34.0 'male' 0 0]
#  [535 'Portaluppi, Mr Emilio' '2nd' nan 'male' 1 0]
#  [536 'Pulbaum, Mr Frank' '2nd' nan 'male' 0 0]
#  [537 'Quick, Mrs Frederick C (Jane Richards)' '2nd' 33.0 'female' 1 1]
#  [538 'Quick, Miss Phyllis May' '2nd' 2.0 'female' 1 1]
#  [539 'Quick, Miss Winifred Vera' '2nd' 8.0 'female' 1 1]
#  [540 'Reeves, Mr David' '2nd' 36.0 'male' 0 0]
#  [541 'Renouf, Mr Peter Henry' '2nd' 34.0 'male' 0 0]
#  [542 'Renouf, Mrs Peter Henry (Lillian Jefferys)' '2nd' 30.0 'female' 1
#   1]
#  [543 'Reynaldo, Mrs Encarnacion' '2nd' 28.0 'female' 1 1]
#  [544 'Richard, Mr Emil' '2nd' 23.0 'male' 0 0]
#  [545 'Richards, Master George Sidney' '2nd' 0.8 'male' 1 0]
#  [546 'Richards, Mrs Sidney (Emily Hocking)' '2nd' 25.0 'female' 1 1]
#  [547 'Richards, Master William Rowe' '2nd' 3.0 'male' 1 0]
#  [548 'Ridsdale, Miss Lucy' '2nd' 50.0 'female' 1 1]
#  [549 'Rogers, Mr Harry' '2nd' nan 'male' 0 0]
#  [550 'Rugg, Miss Emily' '2nd' 21.0 'female' 1 1]
#  [551 'Sedgwick, Mr Charles Frederick Waddington' '2nd' nan 'male' 0 0]
#  [552 'Sharp, Mr Percival' '2nd' nan 'male' 0 0]
#  [553 'Shelley, Mrs William (Imanita)' '2nd' 25.0 'female' 1 1]
#  [554 'Silven, Miss Lyyli' '2nd' 18.0 'female' 1 1]
#  [555 'Sincock, Miss Maude' '2nd' 20.0 'female' 1 1]
#  [556 'Siukonnen, Miss Anna' '2nd' 30.0 'female' 1 1]
#  [557 'Sjostedt, Mr Ernst Adolf' '2nd' 59.0 'male' 0 0]
#  [558 'Slayter, Miss Hilda Mary' '2nd' 30.0 'female' 1 1]
#  [559 'Slemen, Mr Richard James' '2nd' 35.0 'male' 0 0]
#  [560 'Smith (Schmidt), Mr Augustus' '2nd' 22.0 'male' 0 0]
#  [561 'Smith, Miss Marion' '2nd' nan 'female' 1 1]
#  [562 'Sobey, Mr Hayden' '2nd' 25.0 'male' 0 0]
#  [563 'Stanton, Mr Samuel Ward' '2nd' 41.0 'male' 0 0]
#  [564 'Stokes, Mr Philip Joseph' '2nd' 25.0 'male' 0 0]
#  [565 'Sweet, Mr George' '2nd' 14.0 'male' 0 0]
#  [566 'Toomey, Miss Ellen' '2nd' 50.0 'female' 1 1]
#  [567 'Troupiansky, Mr Moses Aaron' '2nd' 22.0 'male' 0 0]
#  [568 'Trout, Mrs William H (Jessie L)' '2nd' nan 'female' 1 1]
#  [569 'Troutt, Miss Edwina Celia' '2nd' 27.0 'female' 1 1]
#  [570 'Turpin, Mr William John' '2nd' 29.0 'male' 0 0]
#  [571 'Turpin, Mrs William John (Dorothy Anne Wonnacott)' '2nd' 27.0
#   'female' 0 1]
#  [572 'Veale, Mr James' '2nd' 30.0 'male' 0 0]
#  [573 'Waelens, Mr Achille' '2nd' 22.0 'male' 0 0]
#  [574 'Walcroft, Miss Nellie' '2nd' 35.0 'female' 1 1]
#  [575 'Ware, Mr John James' '2nd' 30.0 'male' 0 0]
#  [576 'Ware, Mrs John James (Florence Louise Long)' '2nd' 28.0 'female' 1
#   1]
#  [577 'Ware, Mr William J' '2nd' 23.0 'male' 0 0]
#  [578 'Watson, Mr Ennis Hastings' '2nd' nan 'male' 0 0]
#  [579 'Watt, Miss Bertha' '2nd' 12.0 'female' 1 1]
#  [580 'Watt, Mrs James (Bessie Inglis Milne)' '2nd' 40.0 'female' 1 1]
#  [581 'Webber, Miss Susan' '2nd' 36.0 'female' 1 1]
#  [582 'Weisz, Mr Leopold' '2nd' 28.0 'male' 0 0]
#  [583 'Weisz, Mrs Leopold (Mathilde)' '2nd' 32.0 'female' 1 1]
#  [584 'Wells, Mrs Arthur H (Addie Trevaskis)' '2nd' 29.0 'female' 1 1]
#  [585 'Wells, Miss Joan' '2nd' 4.0 'female' 1 1]
#  [586 'Wells, Master Ralph Lester' '2nd' 2.0 'male' 1 0]
#  [587 'West, Miss Barbara J' '2nd' nan 'female' 1 1]
#  [588 'West, Miss Constance Mirium' '2nd' nan 'female' 1 1]
#  [589 'West, Mr Edwy Arthur' '2nd' 36.0 'male' 0 0]
#  [590 'West, Mrs Edwy Arthur (Ada Mary)' '2nd' 33.0 'female' 1 1]
#  [591 'Wheadon, Mr Edward' '2nd' nan 'male' 0 0]
#  [592 'Wheeler, Mr Edwin' '2nd' nan 'male' 0 0]
#  [593 'Wheeler, Mr Frederick' '2nd' nan 'male' 0 0]
#  [594 'Wilhelms, Mr Charles' '2nd' 32.0 'male' 1 0]
#  [595 'Wilkinson, Mrs Elizabeth Anne' '2nd' nan 'female' 1 1]
#  [596 'Williams, Mr Charles Eugene' '2nd' nan 'male' 1 0]
#  [597 'Wright, Miss Marion' '2nd' 26.0 'female' 1 1]
#  [598 'Yrois, Miss Henriette' '2nd' nan 'female' 0 1]
#  [599 'Aldworth, Mr Charles Augustus' '2nd' 30.0 'male' 0 0]
#  [600 'Brown, Miss Mildred' '2nd' 24.0 'female' 1 1]
#  [601 'Pernot, Mr Rene' '2nd' nan 'male' 0 0]
#  [602 'Swane, Mr George' '2nd' 18.0 'male' 0 0]
#  [603 'Abbing, Mr Anthony' '3rd' 42.0 'male' 0 0]
#  [604 'Abbott, Master Eugene Joseph' '3rd' 13.0 'male' 0 0]
#  [605 'Abbott, Mr Rossmore Edward' '3rd' 16.0 'male' 0 0]
#  [606 'Abbott, Mrs Stanton (Rosa)' '3rd' 35.0 'female' 1 1]
#  [607 'Abelseth, Miss Anna Karen' '3rd' 16.0 'female' 1 1]
#  [608 'Abelseth, Mr Olaus' '3rd' 25.0 'male' 1 0]
#  [609 'Abraham, Mrs Joseph (Sophie Easu)' '3rd' 18.0 'female' 1 1]
#  [610 'Abrahamsson, Mr August' '3rd' 20.0 'male' 1 0]
#  [611 'Adahl, Mr Mauritz Nils Martin' '3rd' 30.0 'male' 0 0]
#  [612 'Adams, Mr John' '3rd' 26.0 'male' 0 0]
#  [613 'Ahlin, Mrs Johanna Persdotter' '3rd' 40.0 'female' 0 1]
#  [614 'Ahmed, Mr Ali' '3rd' 24.0 'male' 0 0]
#  [615 'Aijo-Nirva, Mr Isak' '3rd' 41.0 'male' 0 0]
#  [616 'Aks, Mrs Sam (Leah Rosen)' '3rd' 18.0 'female' 1 1]
#  [617 'Aks, Master Philip' '3rd' 0.83 'male' 1 0]
#  [618 'Alexander, Mr William' '3rd' 23.0 'male' 0 0]
#  [619 'Alhomaki, Mr Ilmari Rudolf' '3rd' 20.0 'male' 0 0]
#  [620 'Ali, Mr William' '3rd' 25.0 'male' 0 0]
#  [621 'Allen, Mr William Henry' '3rd' 35.0 'male' 0 0]
#  [622 'Allum, Mr Owen George' '3rd' 17.0 'male' 0 0]
#  [623 'Andersen, Mr Albert Karvin' '3rd' 32.0 'male' 0 0]
#  [624 'Andersen, Mr Thor Olsvigen' '3rd' 20.0 'male' 0 0]
#  [625 'Andersson, Mr Anders Johan' '3rd' 39.0 'male' 0 0]
#  [626 'Andersson, Mrs Anders Johan (Alfrida K Brogren)' '3rd' 39.0
#   'female' 0 1]
#  [627 'Andersson, Miss Ebba Iris' '3rd' 6.0 'female' 0 1]
#  [628 'Andersson, Miss Ellis Anna Maria' '3rd' 2.0 'female' 0 1]
#  [629 'Andersson, Miss Erna' '3rd' 17.0 'female' 1 1]
#  [630 'Andersson, Miss Ida Augusta Margareta' '3rd' 38.0 'female' 0 1]
#  [631 'Andersson, Miss Ingeborg Constancia' '3rd' 9.0 'female' 0 1]
#  [632 'Andersson, Mr Johan Samuel' '3rd' 26.0 'male' 0 0]
#  [633 'Andersson, Miss Sigrid Elizabeth' '3rd' 11.0 'female' 0 1]
#  [634 'Andersson, Master Sigvard Harald Elias' '3rd' 4.0 'male' 0 0]
#  [635 'Andreasson, Mr Paul Edvin' '3rd' 20.0 'male' 0 0]
#  [636 'Angheloff, Mr Minko' '3rd' 26.0 'male' 0 0]
#  [637 'Arnold, Mr Josef' '3rd' 25.0 'male' 0 0]
#  [638 'Arnold, Mrs Josef (Josephine Frank)' '3rd' 18.0 'female' 0 1]
#  [639 'Aronsson, Mr Ernst Axel Algot' '3rd' 24.0 'male' 0 0]
#  [640 'Asim, Mr Adola' '3rd' 35.0 'male' 0 0]
#  [641 'Asplund, Mr Carl Oscar Vilhelm Gustafsson' '3rd' 40.0 'male' 0 0]
#  [642 'Asplund, Mrs Carl Oscar (Selma Augusta Johansson)' '3rd' 38.0
#   'female' 1 1]
#  [643 'Asplund, Master Carl Edgar' '3rd' 5.0 'male' 0 0]
#  [644 'Asplund, Master Clarence Gustaf Hugo' '3rd' 9.0 'male' 0 0]
#  [645 'Aspland, Master Edvin Rojj Felix' '3rd' 3.0 'male' 1 0]
#  [646 'Asplund, Master Filip Oscar' '3rd' 13.0 'male' 0 0]
#  [647 'Asplund, Mr John Charles' '3rd' 23.0 'male' 1 0]
#  [648 'Asplund, Miss Lillian Gertrud' '3rd' 5.0 'female' 1 1]
#  [649 'Assaf, Mr Gerios' '3rd' nan 'male' 0 0]
#  [650 'Assaf, Mrs Mariana' '3rd' 45.0 'female' 1 1]
#  [651 'Assam, Mr Ali' '3rd' 23.0 'male' 0 0]
#  [652 'Attalah, Miss Malaka' '3rd' 17.0 'female' 0 1]
#  [653 'Attala (Kalil), Mr Solomon' '3rd' 27.0 'male' 0 0]
#  [654 'Augustsson, Mr Albert' '3rd' 23.0 'male' 0 0]
#  [655 'Baccos, Mr Rafoul' '3rd' 20.0 'male' 0 0]
#  [656 'Backstrom, Mr Karl Alfred' '3rd' 32.0 'male' 0 0]
#  [657 'Backstrom, Mrs Karl Alfred (Maria Mathilda Gustafsson)' '3rd' 33.0
#   'female' 1 1]
#  [658 'Baclini, Miss Eugenie' '3rd' 3.0 'female' 1 1]
#  [659 'Baclini, Miss Helene' '3rd' nan 'female' 1 1]
#  [660 'Baclini, Miss Maria' '3rd' nan 'female' 1 1]
#  [661 'Baclini, Mrs Solomon (Latifa)' '3rd' nan 'female' 1 1]
#  [662 'Badman, Miss Emily Louisa' '3rd' 18.0 'female' 1 1]
#  [663 'Badt, Mr Mohamed' '3rd' 40.0 'male' 0 0]
#  [664 'Balkic, Mr Cerin' '3rd' 26.0 'male' 0 0]
#  [665 'Banoura, Miss Ayout' '3rd' 15.0 'female' 1 1]
#  [666 'Barbara, Mrs Catherine' '3rd' 45.0 'female' 0 1]
#  [667 'Barbara, Miss Saude' '3rd' 18.0 'female' 0 1]
#  [668 'Barry, Miss Julia' '3rd' 27.0 'female' 0 1]
#  [669 'Barton, Mr David' '3rd' 22.0 'male' 0 0]
#  [670 'Beavan, Mr William Thomas' '3rd' 19.0 'male' 0 0]
#  [671 'Bengtsson, Mr John Viktor' '3rd' 26.0 'male' 0 0]
#  [672 'Berglund, Mr Karl Ivar Sven' '3rd' 22.0 'male' 0 0]
#  [673 'Betros, Mr Tannous' '3rd' 20.0 'male' 0 0]
#  [674 'Bing, Mr Lee' '3rd' 32.0 'male' 1 0]
#  [675 'Birkeland, Mr Hans' '3rd' 21.0 'male' 0 0]
#  [676 'Bjorklund, Ernst Herbert' '3rd' 18.0 'male' 0 0]
#  [677 'Bostandyeff, Mr Guentcho' '3rd' 26.0 'male' 0 0]
#  [678 'Boulos, Master Akar' '3rd' 6.0 'male' 0 0]
#  [679 'Boulos, Mr Hanna' '3rd' nan 'male' 0 0]
#  [680 'Boulos, Mrs Joseph (Sultana)' '3rd' nan 'female' 0 1]
#  [681 'Boulos, Miss Laura' '3rd' 9.0 'female' 0 1]
#  [682 'Bourke, Mr John' '3rd' 40.0 'male' 0 0]
#  [683 'Bourke, Mrs John (Catherine)' '3rd' 32.0 'female' 0 1]
#  [684 'Bourke, Miss Mary' '3rd' nan 'female' 0 1]
#  [685 'Bowen, Mr David' '3rd' 26.0 'male' 0 0]
#  [686 'Bradley, Miss Bridget Delia' '3rd' 18.0 'female' 1 1]
#  [687 'Braf, Miss Elin Ester Maria' '3rd' 20.0 'female' 0 1]
#  [688 'Brahim, Mr Youssef' '3rd' nan 'male' 0 0]
#  [689 'Braund, Mr Lewis Richard' '3rd' 29.0 'male' 0 0]
#  [690 'Braund, Mr Owen Harris' '3rd' 22.0 'male' 0 0]
#  [691 'Brobek, Mr Karl Rudolf' '3rd' 22.0 'male' 0 0]
#  [692 'Brocklebank, Mr William Alfred' '3rd' 35.0 'male' 0 0]
#  [693 'Buckley, Mr Daniel' '3rd' 21.0 'male' 1 0]
#  [694 'Buckley, Miss Katherine' '3rd' 20.0 'female' 0 1]
#  [695 'Burke, Mr Jeremiah' '3rd' 19.0 'male' 0 0]
#  [696 'Burns, Miss Mary Delia' '3rd' 18.0 'female' 0 1]
#  [697 'Cacic, Mr Grego' '3rd' 18.0 'male' 0 0]
#  [698 'Cacic, Mr Luka' '3rd' 38.0 'male' 0 0]
#  [699 'Cacic, Mr Manda' '3rd' nan 'male' 0 0]
#  [700 'Cacic, Mr Maria' '3rd' 30.0 'male' 0 0]
#  [701 'Calic, Mr Peter' '3rd' 17.0 'male' 0 0]
#  [702 'Canavan, Miss Mary' '3rd' 21.0 'female' 0 1]
#  [703 'Canavan, Mr Patrick' '3rd' 21.0 'male' 0 0]
#  [704 'Cann, Mr Ernest' '3rd' 21.0 'male' 0 0]
#  [705 'Caram (Kareem), Mr Joseph' '3rd' nan 'male' 0 0]
#  [706 'Caram (Kareem), Mrs Joseph (Maria Elias)' '3rd' nan 'female' 0 1]
#  [707 'Carlsson, Mr Carl Robert' '3rd' 24.0 'male' 0 0]
#  [708 'Carlsson, Mr Frans Olof' '3rd' 33.0 'male' 0 0]
#  [709 'Carlsson, Mr Julius' '3rd' 33.0 'male' 0 0]
#  [710 'Carlsson, Mr August Sigfrid' '3rd' 28.0 'male' 0 0]
#  [711 'Carr, Miss Helen' '3rd' 16.0 'female' 1 1]
#  [712 'Carr, Miss Jeannie' '3rd' 37.0 'female' 0 1]
#  [713 'Carver, Mr Alfred John' '3rd' 28.0 'male' 0 0]
#  [714 'Cassem, Mr Nassef Belmenly' '3rd' nan 'male' 1 0]
#  [715 'Celotti, Mr Francesco' '3rd' 24.0 'male' 0 0]
#  [716 'Chartens, Mr David' '3rd' 21.0 'male' 0 0]
#  [717 'Chebab, Mr Emir Farres' '3rd' nan 'male' 0 0]
#  [718 'Chip, Mr Chang' '3rd' 32.0 'male' 0 0]
#  [719 'Christmann, Mr Emil' '3rd' 29.0 'male' 0 0]
#  [720 'Chronopoulos, Mr Apostolos' '3rd' 26.0 'male' 0 0]
#  [721 'Chronopoulos, Mr Demetrios' '3rd' 18.0 'male' 0 0]
#  [722 'Coelho, Mr Domingos Fernandes' '3rd' 20.0 'male' 0 0]
#  [723 'Cohen, Mr Gurshon (Gus)' '3rd' 19.0 'male' 1 0]
#  [724 'Colbert, Mr Patrick' '3rd' 24.0 'male' 0 0]
#  [725 'Coleff, Mr Fotio' '3rd' 24.0 'male' 0 0]
#  [726 'Coleff, Mr Peyo' '3rd' 36.0 'male' 0 0]
#  [727 'Conlin, Mr Thomas Henry' '3rd' 31.0 'male' 0 0]
#  [728 'Connaghton, Mr Michael' '3rd' 31.0 'male' 0 0]
#  [729 'Connolly, Miss Kate' '3rd' 30.0 'female' 0 1]
#  [730 'Connolly, Miss Kate' '3rd' 22.0 'female' 1 1]
#  [731 'Connors, Mr Patrick' '3rd' nan 'male' 0 0]
#  [732 'Cook, Mr Jacob' '3rd' 43.0 'male' 0 0]
#  [733 'Cor, Mr Bartol' '3rd' 35.0 'male' 0 0]
#  [734 'Cor, Mr Ivan' '3rd' 27.0 'male' 0 0]
#  [735 'Cor, Mr Ludovik' '3rd' 19.0 'male' 0 0]
#  [736 'Corn, Mr Harry' '3rd' 30.0 'male' 0 0]
#  [737 'Coutts, Mrs William (Minnie)' '3rd' 36.0 'female' 1 1]
#  [738 'Coutts, Master Neville' '3rd' 3.0 'male' 1 0]
#  [739 'Coutts, Master William Leslie' '3rd' 9.0 'male' 1 0]
#  [740 'Coxon, Mr Daniel' '3rd' 59.0 'male' 0 0]
#  [741 'Crease, Mr Ernest James' '3rd' 19.0 'male' 0 0]
#  [742 'Cribb, Mr John Hatfield' '3rd' 44.0 'male' 0 0]
#  [743 'Cribb, Miss Laura Alice' '3rd' 17.0 'female' 1 1]
#  [744 'Daher, Mr Tannous' '3rd' nan 'male' 0 0]
#  [745 'Dahl, Mr Charles Edward' '3rd' 45.0 'male' 1 0]
#  [746 'Dahlberg, Miss Gerda Ulrika' '3rd' 22.0 'female' 0 1]
#  [747 'Dakic, Mr Branko' '3rd' 19.0 'male' 0 0]
#  [748 'Daly, Mr Eugene' '3rd' 29.0 'male' 1 0]
#  [749 'Daly, Miss Marcella' '3rd' 30.0 'female' 1 1]
#  [750 'Danbom, Mr Ernst Gilbert' '3rd' 34.0 'male' 0 0]
#  [751 'Danbom, Mrs Ernst Gilbert (Anna Sigrid Maria Brogren)' '3rd' 28.0
#   'female' 0 1]
#  [752 'Danbom, Master Gilbert Sigvard Emanuel' '3rd' 0.33 'male' 0 0]
#  [753 'Danoff, Mr Yoto' '3rd' 27.0 'male' 0 0]
#  [754 'Dantchoff, Mr Khristo' '3rd' 25.0 'male' 0 0]
#  [755 'Davies, Mr Alfred' '3rd' 24.0 'male' 0 0]
#  [756 'Davies, Mr Evan' '3rd' 22.0 'male' 0 0]
#  [757 'Davies, Mr John' '3rd' 21.0 'male' 0 0]
#  [758 'Davies, Mr Joseph' '3rd' 17.0 'male' 0 0]
#  [759 'Davison, Mr Thomas Henry' '3rd' nan 'male' 0 0]
#  [760 'Davison, Mrs Thomas Henry (Mary Finck)' '3rd' nan 'female' 1 1]
#  [761 'Dean, Mr Bertram' '3rd' 26.0 'male' 0 0]
#  [762 'Dean, Mrs Bertram (Eva)' '3rd' 33.0 'female' 1 1]
#  [763 'Dean, Master Bertram Vere' '3rd' 1.0 'male' 1 0]
#  [764 'Dean, Miss Elizabeth Gladys (Millvena)' '3rd' 0.17 'female' 1 1]
#  [765 'Delalic, Mr Regyo' '3rd' 25.0 'male' 0 0]
#  [766 'De Messemaeker, Mr William Joseph' '3rd' 36.0 'male' 1 0]
#  [767 'De Messemaeker, Mrs William Joseph (Anna)' '3rd' 36.0 'female' 1 1]
#  [768 'De Mulder, Mr Theo' '3rd' 30.0 'male' 1 0]
#  [769 'Denkoff, Mr Mito' '3rd' nan 'male' 0 0]
#  [770 'Dennis, Mr Samuel' '3rd' 23.0 'male' 0 0]
#  [771 'Dennis, Mr William' '3rd' 26.0 'male' 0 0]
#  [772 'Devaney, Miss Margaret' '3rd' 19.0 'female' 1 1]
#  [773 'Dewan, Mr Frank' '3rd' 65.0 'male' 0 0]
#  [774 'Dibo, Mr Elias' '3rd' nan 'male' 0 0]
#  [775 'Dimic, Mr Jovan' '3rd' 42.0 'male' 0 0]
#  [776 'Dintcheff, Mr Valtcho' '3rd' 43.0 'male' 0 0]
#  [777 'Dooley, Mr Patrick' '3rd' 32.0 'male' 0 0]
#  [778 'Dorkings, Mr Edward Arthur' '3rd' 19.0 'male' 1 0]
#  [779 'Dowdell, Miss Elizabeth' '3rd' 30.0 'female' 1 1]
#  [780 'Doyle, Miss Elizabeth' '3rd' 24.0 'female' 0 1]
#  [781 'Drapkin, Miss Jennie' '3rd' 23.0 'female' 1 1]
#  [782 'Drazonovic, Mr Josef' '3rd' nan 'male' 0 0]
#  [783 'Driscoll, Miss Bridget' '3rd' 24.0 'female' 1 1]
#  [784 'Duquemin, Mr Joseph' '3rd' 24.0 'male' 1 0]
#  [785 'Dyker, Mr Adolf Fredrik' '3rd' 23.0 'male' 0 0]
#  [786 'Dyker, Mrs Adolf Fredrik (Anna Elizabeth Judith Andersson)' '3rd'
#   22.0 'female' 1 1]
#  [787 'Econovic, Mr Joso' '3rd' nan 'male' 0 0]
#  [788 'Edvardsson, Mr Gustaf Hjalmar' '3rd' 18.0 'male' 0 0]
#  [789 'Eklund, Mr Hans Linus' '3rd' 16.0 'male' 0 0]
#  [790 'Ekstrom, Mr Johan' '3rd' 45.0 'male' 0 0]
#  [791 'Elias, Mr Elias' '3rd' nan 'male' 0 0]
#  [792 'Elias, Mr John' '3rd' nan 'male' 0 0]
#  [793 'Elias, Mr Joseph' '3rd' nan 'male' 0 0]
#  [794 'Elsbury, Mr James' '3rd' 47.0 'male' 0 0]
#  [795 'Emanuel, Miss Virginia Ethel' '3rd' 5.0 'female' 1 1]
#  [796 'Emmeth, Mr Thomas' '3rd' nan 'male' 0 0]
#  [797 'Everett, Thomas James' '3rd' nan 'male' 0 0]
#  [798 'Farrell, Mr James' '3rd' nan 'male' 0 0]
#  [799 'Finoli, Mr Luigi' '3rd' nan 'male' 1 0]
#  [800 'Fischer, Mr Eberhard Telander' '3rd' nan 'male' 0 0]
#  [801 'Flynn, Mr James' '3rd' nan 'male' 0 0]
#  [802 'Flynn, Mr John' '3rd' nan 'male' 0 0]
#  [803 'Foley, Mr Joseph' '3rd' nan 'male' 0 0]
#  [804 'Foley, Mr William' '3rd' nan 'male' 0 0]
#  [805 'Foo, Mr Choong' '3rd' nan 'male' 1 0]
#  [806 'Ford, Mr Arthur' '3rd' nan 'male' 0 0]
#  [807 'Ford, Miss Doolina Margaret' '3rd' 21.0 'female' 0 1]
#  [808 'Ford, Mr Edward Watson' '3rd' 18.0 'male' 0 0]
#  [809 'Ford, Miss Maggie' '3rd' 9.0 'female' 0 1]
#  [810 'Ford, Mrs Edward (Margaret Ann)' '3rd' 48.0 'female' 0 1]
#  [811 'Ford, Mr Neil Watson' '3rd' 16.0 'male' 0 0]
#  [812 'Fox, Mr Patrick' '3rd' nan 'male' 0 0]
# ...
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 25.0 'male' 1 0]
#  ['3rd' nan 'female' 0 1]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'female' 0 1]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 18.0 'female' 1 1]
#  ['3rd' 63.0 'female' 1 1]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 18.0 'female' 0 1]
#  ['3rd' 31.0 'male' 0 0]
#  ['3rd' 31.0 'female' 0 1]
#  ['3rd' 15.0 'male' 0 0]
#  ['3rd' 28.0 'male' 0 0]
#  ['3rd' 36.0 'male' 0 0]
#  ['3rd' 28.0 'male' 0 0]
#  ['3rd' 10.0 'female' 0 1]
#  ['3rd' 36.0 'male' 0 0]
#  ['3rd' 30.0 'female' 0 1]
#  ['3rd' 22.0 'male' 1 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 29.0 'male' 0 0]
#  ['3rd' 47.0 'male' 0 0]
#  ['3rd' 14.0 'female' 0 1]
#  ['3rd' 22.0 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 1 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 51.0 'male' 0 0]
#  ['3rd' 18.0 'male' 0 0]
#  ['3rd' 45.0 'female' 1 1]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 28.0 'male' 0 0]
#  ['3rd' 21.0 'male' 0 0]
#  ['3rd' 27.0 'male' 0 0]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' 36.0 'male' 0 0]
#  ['3rd' nan 'male' 1 0]
#  ['3rd' 27.0 'male' 0 0]
#  ['3rd' 15.0 'female' 1 1]
#  ['3rd' nan 'male' 0 0]
#  ['3rd' nan 'female' 0 1]
#  ['3rd' nan 'female' 0 1]
#  ['3rd' 27.0 'male' 0 0]
#  ['3rd' 26.0 'male' 0 0]
#  ['3rd' 22.0 'male' 0 0]
#  ['3rd' 24.0 'male' 0 0]
#  ['3rd' 29.0 'male' 0 0]]
#
# 28. Length b:
# 1313
#
# 29. Prrint element of (NumPy array) ndarray b in *second* row, *third* column:
# female
#
# 30. Print all records for NumPy array column 2:
# [29.0 2.0 30.0 25.0 0.92 47.0 63.0 39.0 58.0 71.0 47.0 19.0 nan nan nan
#  50.0 24.0 36.0 37.0 47.0 26.0 25.0 25.0 19.0 28.0 45.0 39.0 30.0 58.0 nan
#  45.0 22.0 nan 41.0 48.0 nan 44.0 59.0 60.0 45.0 nan 53.0 58.0 36.0 33.0
#  nan nan 36.0 36.0 14.0 11.0 49.0 nan 36.0 nan 46.0 47.0 27.0 31.0 nan nan
#  nan nan 27.0 26.0 nan nan 64.0 37.0 39.0 55.0 nan 70.0 69.0 36.0 39.0
#  38.0 nan 27.0 31.0 27.0 nan 31.0 17.0 nan nan 4.0 27.0 50.0 48.0 49.0
#  48.0 39.0 23.0 53.0 36.0 nan nan 30.0 24.0 19.0 28.0 23.0 64.0 60.0 nan
#  49.0 nan 44.0 22.0 60.0 48.0 37.0 35.0 47.0 22.0 45.0 49.0 nan 71.0 54.0
#  38.0 19.0 58.0 45.0 23.0 46.0 25.0 21.0 48.0 49.0 45.0 36.0 nan 55.0 52.0
#  24.0 nan nan nan 16.0 44.0 51.0 42.0 35.0 35.0 38.0 35.0 nan 50.0 49.0
#  46.0 nan 58.0 41.0 nan 42.0 40.0 nan nan nan 42.0 55.0 50.0 16.0 nan 29.0
#  21.0 30.0 15.0 30.0 nan nan nan 46.0 54.0 36.0 28.0 nan 65.0 33.0 44.0
#  37.0 nan 55.0 47.0 36.0 58.0 31.0 23.0 19.0 64.0 nan 64.0 22.0 28.0 nan
#  nan 22.0 nan nan 18.0 17.0 52.0 46.0 56.0 nan nan 43.0 31.0 nan nan 33.0
#  nan 27.0 55.0 54.0 nan 61.0 48.0 18.0 13.0 21.0 nan nan nan 34.0 40.0
#  36.0 50.0 39.0 56.0 28.0 56.0 56.0 24.0 18.0 nan 24.0 23.0 45.0 40.0 6.0
#  57.0 nan 32.0 62.0 54.0 43.0 52.0 nan 62.0 67.0 63.0 61.0 46.0 52.0 39.0
#  18.0 48.0 nan 49.0 39.0 17.0 46.0 nan 31.0 nan 61.0 47.0 64.0 60.0 60.0
#  55.0 54.0 21.0 57.0 45.0 31.0 50.0 50.0 27.0 20.0 51.0 nan 21.0 nan nan
#  36.0 nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  40.0 nan nan 32.0 nan nan nan nan nan nan 33.0 nan nan nan nan nan 30.0
#  28.0 18.0 nan 34.0 32.0 57.0 18.0 23.0 36.0 28.0 51.0 32.0 19.0 28.0 36.0
#  4.0 1.0 12.0 34.0 19.0 23.0 26.0 nan 27.0 15.0 45.0 40.0 20.0 25.0 36.0
#  25.0 nan 42.0 26.0 26.0 0.83 31.0 nan 19.0 54.0 44.0 52.0 30.0 30.0 nan
#  nan 29.0 nan 29.0 27.0 24.0 35.0 31.0 8.0 22.0 30.0 nan 20.0 nan 21.0
#  49.0 8.0 28.0 18.0 nan 28.0 22.0 25.0 18.0 32.0 18.0 nan 42.0 34.0 8.0
#  nan nan 23.0 21.0 19.0 nan nan nan 38.0 nan 38.0 35.0 35.0 38.0 24.0 16.0
#  26.0 45.0 24.0 21.0 22.0 nan 34.0 30.0 50.0 30.0 23.0 1.0 44.0 28.0 6.0
#  30.0 nan 43.0 45.0 7.0 24.0 24.0 49.0 48.0 nan 34.0 32.0 21.0 18.0 53.0
#  23.0 21.0 nan 52.0 42.0 36.0 21.0 41.0 nan nan 33.0 17.0 nan nan nan nan
#  nan nan 23.0 34.0 nan 22.0 nan nan 45.0 nan nan 31.0 30.0 26.0 nan 34.0
#  26.0 22.0 1.0 3.0 nan nan nan 25.0 nan 48.0 nan 57.0 nan nan nan 2.0 nan
#  27.0 19.0 30.0 20.0 45.0 nan 46.0 41.0 13.0 19.0 30.0 48.0 71.0 54.0 nan
#  nan 64.0 32.0 18.0 2.0 32.0 3.0 26.0 19.0 nan 20.0 29.0 39.0 22.0 nan
#  24.0 nan 28.0 nan 50.0 20.0 40.0 42.0 21.0 32.0 34.0 nan nan 33.0 2.0 8.0
#  36.0 34.0 30.0 28.0 23.0 0.8 25.0 3.0 50.0 nan 21.0 nan nan 25.0 18.0
#  20.0 30.0 59.0 30.0 35.0 22.0 nan 25.0 41.0 25.0 14.0 50.0 22.0 nan 27.0
#  29.0 27.0 30.0 22.0 35.0 30.0 28.0 23.0 nan 12.0 40.0 36.0 28.0 32.0 29.0
#  4.0 2.0 nan nan 36.0 33.0 nan nan nan 32.0 nan nan 26.0 nan 30.0 24.0 nan
#  18.0 42.0 13.0 16.0 35.0 16.0 25.0 18.0 20.0 30.0 26.0 40.0 24.0 41.0
#  18.0 0.83 23.0 20.0 25.0 35.0 17.0 32.0 20.0 39.0 39.0 6.0 2.0 17.0 38.0
#  9.0 26.0 11.0 4.0 20.0 26.0 25.0 18.0 24.0 35.0 40.0 38.0 5.0 9.0 3.0
#  13.0 23.0 5.0 nan 45.0 23.0 17.0 27.0 23.0 20.0 32.0 33.0 3.0 nan nan nan
#  18.0 40.0 26.0 15.0 45.0 18.0 27.0 22.0 19.0 26.0 22.0 20.0 32.0 21.0
#  18.0 26.0 6.0 nan nan 9.0 40.0 32.0 nan 26.0 18.0 20.0 nan 29.0 22.0 22.0
#  35.0 21.0 20.0 19.0 18.0 18.0 38.0 nan 30.0 17.0 21.0 21.0 21.0 nan nan
#  24.0 33.0 33.0 28.0 16.0 37.0 28.0 nan 24.0 21.0 nan 32.0 29.0 26.0 18.0
#  20.0 19.0 24.0 24.0 36.0 31.0 31.0 30.0 22.0 nan 43.0 35.0 27.0 19.0 30.0
#  36.0 3.0 9.0 59.0 19.0 44.0 17.0 nan 45.0 22.0 19.0 29.0 30.0 34.0 28.0
#  0.33 27.0 25.0 24.0 22.0 21.0 17.0 nan nan 26.0 33.0 1.0 0.17 25.0 36.0
#  36.0 30.0 nan 23.0 26.0 19.0 65.0 nan 42.0 43.0 32.0 19.0 30.0 24.0 23.0
#  nan 24.0 24.0 23.0 22.0 nan 18.0 16.0 45.0 nan nan nan 47.0 5.0 nan nan
#  nan nan nan nan nan nan nan nan nan 21.0 18.0 9.0 48.0 16.0 nan nan 25.0
#  nan 38.0 22.0 16.0 nan 33.0 nan 9.0 41.0 38.0 40.0 43.0 14.0 16.0 9.0
#  10.0 6.0 11.0 40.0 32.0 nan 20.0 37.0 28.0 19.0 24.0 17.0 nan nan 28.0
#  24.0 20.0 41.0 45.0 26.0 21.0 nan nan nan nan nan 27.0 nan 18.0 26.0 23.0
#  22.0 nan nan nan 28.0 22.0 2.0 43.0 nan 27.0 nan nan 42.0 nan nan 27.0
#  25.0 nan 27.0 nan 19.0 20.0 48.0 17.0 nan nan 34.0 22.0 33.0 32.0 29.0
#  26.0 49.0 1.0 33.0 4.0 24.0 19.0 nan nan nan nan nan 32.0 27.0 21.0 32.0
#  20.0 17.0 21.0 30.0 21.0 23.0 22.0 4.0 39.0 nan 20.0 nan nan 21.0 44.0
#  42.0 21.0 24.0 nan nan nan 25.0 22.0 22.0 39.0 26.0 4.0 22.0 26.0 1.5
#  36.0 18.0 nan 25.0 nan 37.0 nan nan nan 22.0 20.0 26.0 29.0 29.0 22.0 nan
#  nan nan nan nan nan 32.0 nan 21.0 21.0 36.0 39.0 25.0 45.0 36.0 30.0 20.0
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan 23.0 nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan 21.0 nan nan nan
#  nan nan nan 1.5 nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan 25.0 nan nan nan nan 18.0 63.0 nan nan nan nan 18.0 31.0 31.0 15.0
#  28.0 36.0 28.0 10.0 36.0 30.0 22.0 nan 29.0 47.0 14.0 22.0 nan nan nan
#  nan nan nan 51.0 18.0 45.0 nan nan nan 28.0 21.0 27.0 nan 36.0 nan 27.0
#  15.0 nan nan nan 27.0 26.0 22.0 24.0 29.0]
#
# 31. Get passenger names:
# rownames
# 1                        Allen, Miss Elisabeth Walton
# 2                         Allison, Miss Helen Loraine
# 3                 Allison, Mr Hudson Joshua Creighton
# 4       Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# 5                       Allison, Master Hudson Trevor
#                             ...
# 1309                               Zakarian, Mr Artun
# 1310                           Zakarian, Mr Maprieder
# 1311                                 Zenni, Mr Philip
# 1312                                 Lievens, Mr Rene
# 1313                                   Zimmerman, Leo
# Name: Name, Length: 1313, dtype: object
#
# 32. Find all passengers with name 'Allison' (using regular expressions):
# None
# <re.Match object; span=(0, 7), match='Allison'>
# <re.Match object; span=(0, 7), match='Allison'>
# <re.Match object; span=(0, 7), match='Allison'>
# <re.Match object; span=(0, 7), match='Allison'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
#
# ***33. Statistical Anlysis (DataFrame notation):***
#
# a) Print mean age:
# 30.397989417989418
#
# b) Print mean age, rounded to two decimal places:
# 30.4
#
# c) Print mean of every column in DataFrame (may not be suitable with certain columns):
#
# d) Print summary statistics (DataFrame notation):
# count    756.000000
# mean      30.397989
# std       14.259049
# min        0.170000
# 25%       21.000000
# 50%       28.000000
# 75%       39.000000
# max       71.000000
# Name: Age, dtype: float64
#
# e) Print minimum age (DataFrame notation):
# 0.17
#
# f) Print maximum age (DataFrame notation):
# 71.0
#
# g) Print median age (DataFrame notation):
# 28.0
#
# h) Print mode age (DataFrame notation):
# 0    22.0
# Name: Age, dtype: float64
#
# i) Print number of values (DataFrame notation):
# 756
#
# ***Graph: Display ages of the first 20 passengers (use code from previos assignment)***
